# %%
# %%javascript
# var nb = IPython.notebook;
# var kernel = IPython.notebook.kernel;
# var command = "NOTEBOOK_FULL_PATH = '" + nb.base_url + nb.notebook_path + "'";
# kernel.execute(command);

# %%
print("NOTEBOOK_FULL_PATH:\n", NOTEBOOK_FULL_PATH)
# Out:
# NOTEBOOK_FULL_PATH:
#  /LSTM-Human-Activity-Recognition/Untitled-Copy1.ipynb

# %%
i = get_ipython()

# %%
s = i.__dict__
with open('tmp.txt', 'w') as f:
    f.write(str(s))

# %%
# !cat tmp.txt | grep out
# Out:
# {'prefilter': <bound method PrefilterManager.prefilter_lines of <IPython.core.prefilter.PrefilterManager object at 0x7f471c4abac8>>, 'custom_exceptions': (), 'more': False, 'sys_excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x7f4726065780>>, 'indent_current_nsp': 0, 'configurables': [<ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>, <IPython.core.history.HistoryManager object at 0x7f471ed2a518>, <IPython.core.prefilter.PrefilterManager object at 0x7f471c4abac8>, <IPython.core.completer.IPCompleter object at 0x7f471c4ba198>, <IPython.core.formatters.DisplayFormatter object at 0x7f471c4c11d0>, <ipykernel.zmqshell.ZMQDisplayPublisher object at 0x7f471c4c1208>, <ipykernel.displayhook.ZMQShellDisplayHook object at 0x7f471c4c1240>, <IPython.core.magics.UserMagics object at 0x7f471c4c12b0>, <IPython.core.magic.MagicsManager object at 0x7f471c4c12e8>, <IPython.core.magics.auto.AutoMagics object at 0x7f471c4c1358>, <IPython.core.magics.basic.BasicMagics object at 0x7f471c4c13c8>, <IPython.core.magics.code.CodeMagics object at 0x7f471c4c1400>, <IPython.core.magics.config.ConfigMagics object at 0x7f471c4c1438>, <IPython.core.magics.display.DisplayMagics object at 0x7f471c4c1470>, <IPython.core.magics.execution.ExecutionMagics object at 0x7f471c4c14a8>, <IPython.core.magics.extension.ExtensionMagics object at 0x7f471c4c14e0>, <IPython.core.magics.history.HistoryMagics object at 0x7f471c4c1518>, <IPython.core.magics.logging.LoggingMagics object at 0x7f471c4c1550>, <IPython.core.magics.namespace.NamespaceMagics object at 0x7f471c4c1588>, <IPython.core.magics.osm.OSMagics object at 0x7f471c4c15c0>, <IPython.core.magics.pylab.PylabMagics object at 0x7f471c4c15f8>, <IPython.core.magics.script.ScriptMagics object at 0x7f471c4c1630>, <ipykernel.zmqshell.KernelMagics object at 0x7f471c4d7358>, <IPython.core.alias.AliasManager object at 0x7f471c4c1320>, <IPython.core.extensions.ExtensionManager object at 0x7f471c4ceb00>, <IPython.core.payload.PayloadManager object at 0x7f471c4d7438>, <ipykernel.comm.manager.CommManager object at 0x7f471c4d7588>, <ipykernel.kernelapp.IPKernelApp object at 0x7f4726065780>, <storemagic.StoreMagics object at 0x7f471c4d7780>, <storemagic.StoreMagics object at 0x7f471c4d7780>], '_cross_validation_lock': False, '_showtraceback': <bound method ZMQInteractiveShell._showtraceback of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>>, 'user_ns': {'_i15': '!cat tmp.txt | grep out', '___': '', '_iii': "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(display(s)))", '_dh': ['/home/ura/diplom/LSTM-Human-Activity-Recognition'], '__package__': None, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>>, '_7': {...}, 'f': <_io.TextIOWrapper name='tmp.txt' mode='w' encoding='UTF-8'>, '_i5': 'globals()', 'Out': {5: {...}, 7: {...}}, 's': {...}, 'i': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>, '__doc__': 'Automatically created module for IPython interactive environment', '_i16': "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(s))", '_': {...}, '_i3': 'display(123456789)', '_i14': '!cat tmp.txt grep out', '_i12': '!cat tmp.txt grep out', 'In': ['', 'display(123456789)', 'globals()["Out"]', 'display(123456789)', 'globals()["Out"]', 'globals()', 'display(123456789)', 'globals()', 'i = get_ipython()', "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(s)", "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(s)", "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(s))", "get_ipython().system('cat tmp.txt grep out')", "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(display(s)))", "get_ipython().system('cat tmp.txt grep out')", "get_ipython().system('cat tmp.txt | grep out')", "s = i.__dict__\nwith open('tmp.txt', 'w') as f:\n    f.write(str(s))"], '_i6': 'display(123456789)' ...
# All Rights Reserved., 'ImportWarning': <class 'ImportWarning'>, 'len': <built-in function len>, 'ProcessLookupError': <class 'ProcessLookupError'>, 'bytearray': <class 'bytearray'>, 'exec': <built-in function exec>, 'ConnectionError': <class 'ConnectionError'>, '__IPYTHON__': True, 'NotADirectoryError': <class 'NotADirectoryError'>, 'bin': <built-in function bin>, '__package__': '', 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>>, 'RecursionError': <class 'RecursionError'>, 'input': <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f471ecf09b0>>, 'UnicodeEncodeError': <class 'UnicodeEncodeError'>, 'ResourceWarning': <class 'ResourceWarning'>, 'frozenset': <class 'frozenset'>, 'ConnectionResetError': <class 'ConnectionResetError'>, 'dir': <built-in function dir>, 'BaseException': <class 'BaseException'>, 'UserWarning': <class 'UserWarning'>, '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.", 'slice': <class 'slice'>, 'SyntaxError': <class 'SyntaxError'>, 'abs': <built-in function abs>, 'bytes': <class 'bytes'>, 'Warning': <class 'Warning'>, 'UnicodeTranslateError': <class 'UnicodeTranslateError'>, 'license': Type license() to see the full license text, 'Ellipsis': Ellipsis, 'globals': <built-in function globals>, 'UnicodeError': <class 'UnicodeError'>, 'enumerate': <class 'enumerate'>, 'FloatingPointError': <class 'FloatingPointError'>, 'PermissionError': <class 'PermissionError'>, 'compile': <built-in function compile>, 'dict': <class 'dict'>, 'isinstance': <built-in function isinstance>, 'id': <built-in function id>, 'list': <class 'list'>, 'FutureWarning': <class 'FutureWarning'>, 'MemoryError': <class 'MemoryError'>, '__debug__': True, 'oct': <built-in function oct>, 'property': <class 'property'>, 'IsADirectoryError': <class 'IsADirectoryError'>, 'locals': <built-in function locals>, 'Exception': <class 'Exception'>, 'ConnectionAbortedError': <class 'ConnectionAbortedError'>, 'callable': <built-in function callable>, 'SyntaxWarning': <class 'SyntaxWarning'>, 'ValueError': <class 'ValueError'>, 'GeneratorExit': <class 'GeneratorExit'>, 'UnicodeDecodeError': <class 'UnicodeDecodeError'>, 'IndexError': <class 'IndexError'>, 'SystemExit': <class 'SystemExit'>, 'min': <built-in function min>, 'OverflowError': <class 'OverflowError'>, 'KeyboardInterrupt': <class 'KeyboardInterrupt'>, 'complex': <class 'complex'>, '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>), 'max': <built-in function max>, 'map': <class 'map'>, 'ReferenceError': <class 'ReferenceError'>, 'AttributeError': <class 'AttributeError'>, 'BlockingIOError': <class 'BlockingIOError'>, 'super': <class 'super'>, 'sorted': <built-in function sorted>, 'KeyError': <class 'KeyError'>, '__loader__': <class '_frozen_importlib.BuiltinImporter'>, 'SystemError': <class 'SystemError'>, 'FileExistsError': <class 'FileExistsError'>, 'bool': <class 'bool'>, 'hex': <built-in function hex>, 'InterruptedError': <class 'InterruptedError'>, 'NotImplementedError': <class 'NotImplementedError'>, 'ImportError': <class 'ImportError'>, 'set': <class 'set'>, 'int': <class 'int'>, 'issubclass': <built-in function issubclass>, 'staticmethod': <class 'staticmethod'>, 'eval': <built-in function eval>, 'RuntimeWarning': <class 'RuntimeWarning'>, 'EnvironmentError': <class 'OSError'>, 'next': <built-in function next>, '__build_class__': <built-in function __build_class__>, 'classmethod': <class 'classmethod'>, 'ChildProcessError': <class 'ChildProcessError'>, 'float': <class 'float'>, 'OSError': <class 'OSError'>, 'repr': <built-in function repr>, 'ConnectionRefusedError': <class 'ConnectionRefusedError'>, 'FileNotFoundError': <class 'FileNotFoundError'>, 'help': Type help() for interactive help, or help(object) for help about object., 'LookupError': <class ...
#     for supporting Python development.  See www.python.org for more information., 'chr': <built-in function chr>, 'PendingDeprecationWarning': <class 'PendingDeprecationWarning'>, 'BytesWarning': <class 'BytesWarning'>, 'True': True, '__import__': <built-in function __import__>, 'type': <class 'type'>, 'BrokenPipeError': <class 'BrokenPipeError'>, 'StopIteration': <class 'StopIteration'>, 'IOError': <class 'OSError'>, 'getattr': <built-in function getattr>, 'setattr': <built-in function setattr>, 'TypeError': <class 'TypeError'>, 'None': None}}, 'logger': <IPython.core.logger.Logger object at 0x7f471c4ba0b8>, 'events': <IPython.core.events.EventManager object at 0x7f471c4abe48>, 'pycolorize': <function InteractiveShell.init_syntax_highlighting.<locals>.<lambda> at 0x7f471ed07ae8>, 'displayhook': <ipykernel.displayhook.ZMQShellDisplayHook object at 0x7f471c4c1240>, '_main_mod_cache': {}, 'display_pub': <ipykernel.zmqshell.ZMQDisplayPublisher object at 0x7f471c4c1208>, '_orig_sys_module_state': {'stdout': <ipykernel.iostream.OutStream object at 0x7f471eceeb70>, 'stderr': <ipykernel.iostream.OutStream object at 0x7f471ef61f28>, 'excepthook': <bound method IPKernelApp.excepthook of <ipykernel.kernelapp.IPKernelApp object at 0x7f4726065780>>, 'stdin': <_io.TextIOWrapper name='<stdin>' mode='r' encoding='UTF-8'>}, 'compile': <IPython.core.compilerop.CachingCompiler object at 0x7f471ecf0048>, '_trait_validators': {}, 'strdispatchers': {'complete_command': <Strdispatch {'%reset': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4bacf8>, '%aimport': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4baf98>, '%cd': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4bafd0>, '%run': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4baf60>, 'import': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4baeb8>, 'from': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4bac18>}, {}>}, 'home_dir': '/home/ura', 'tempfiles': [], '_last_input_line': "get_ipython().system('cat tmp.txt | grep out')", 'CustomTB': <bound method InteractiveShell.set_custom_exc.<locals>.dummy_handler of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>>, 'dir_stack': [], '_last_traceback': None, 'hooks': {'show_in_pager': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abf60>, 'late_startup_hook': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abf28>, 'pre_prompt_hook': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abf98>, 'pre_run_code_hook': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abfd0>, 'shutdown_hook': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abef0>, 'editor': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abe80>, 'synchronize_with_editor': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4abeb8>, 'clipboard_get': <IPython.core.hooks.CommandChainDispatcher object at 0x7f471c4ba048>}, '_orig_sys_modules_main_name': '__main__', '_trait_values': {'display_page': False, 'readline_use': False, 'wildcards_case_sensitive': True, 'disable_failing_post_execute': False, 'exiter': <IPython.core.autocall.ZMQExitAutocall object at 0x7f471c4ba128>, 'prompt_in1': 'In [\\#]: ', 'execution_count': 16, 'prompt_out': 'Out[\\#]: ', 'prompts_pad_left': True, 'alias_manager': <IPython.core.alias.AliasManager object at 0x7f471c4c1320>, 'prompt_in2': '   .\\D.: ', 'builtin_trap': <IPython.core.builtin_trap.BuiltinTrap object at 0x7f471c4ba080>, 'object_info_string_level': 0, 'logfile': '', 'logappend': '', 'ast_transformers': [], 'display_pub_class': <class 'ipykernel.zmqshell.ZMQDisplayPublisher'>, 'autoindent': False, 'payload_manager': <IPython.core.payload.PayloadManager object at 0x7f471c4d7438>, 'enable_html_pager': False, 'sphinxify_docstring': False, 'colors': 'Neutral', 'input_transformer_manager': <IPython.core.inputsplitter.IPythonInputSplitter object at 0x7f471c440240>, 'filename': ...

# %%
i.
# Out:
# {'In': ['',
#   'display(123456789)',
#   'globals()["Out"]',
#   'display(123456789)',
#   'globals()["Out"]',
#   'globals()',
#   'display(123456789)',
#   'globals()'],
#  'Out': {5: {...}},
#  '_': {...},
#  '_5': {...},
#  '__': '',
#  '___': '',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__loader__': None,
#  '__name__': '__main__',
#  '__package__': None,
#  '__spec__': None,
#  '_dh': ['/home/ura/diplom/LSTM-Human-Activity-Recognition'],
#  '_i': 'display(123456789)',
#  '_i1': 'display(123456789)',
#  '_i2': 'globals()["Out"]',
#  '_i3': 'display(123456789)',
#  '_i4': 'globals()["Out"]',
#  '_i5': 'globals()',
#  '_i6': 'display(123456789)',
#  '_i7': 'globals()',
#  '_ih': ['',
#   'display(123456789)',
#   'globals()["Out"]',
#   'display(123456789)',
#   'globals()["Out"]',
#   'globals()',
#   'display(123456789)',
#   'globals()'],
#  '_ii': 'globals()',
#  '_iii': 'globals()["Out"]',
#  '_oh': {5: {...}},
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7f471c4ba128>,
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7f471ecf0c50>>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7f471c4ba128>}
